# %% [markdown]
# # Multiscale Analysis of the Sustainable Production of 1,3PDO and 3HP
# ## X2 - Sensitivity Analysis: Product Tolerance of the Cell Factories (Max Titer)

# %%
# %reset -f
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Setting up Cell Factory Organisms with Product Tolerance level at 50%, 100%, and 150%

# %%
### Setting up in silico Organisms
import cPickle as pickle
from cbmTES.global_constants import *
from cbmTES.bioreactor import Ecoli, Scerevisiae

## Setting up E. coli
ecoli_model = pickle.load(open('models/ecoli_super.pickle','rb'))

# maximum titer of products are set to 50, 100, 150 g/L for E. coli
titer_limit = {}
titer_limit[r_13PDO] = 100.0/76*1000*0.5
titer_limit[r_3HPP] = 100.0/90*1000*0.5
ecoli_pt50 = Ecoli(ecoli_model, id='ecoli_pt50', titer_limit=titer_limit) # product tolerance at 50%

titer_limit = {}
titer_limit[r_13PDO] = 100.0/76*1000
titer_limit[r_3HPP] = 100.0/90*1000
ecoli_pt100 = Ecoli(ecoli_model, id='ecoli_pt100', titer_limit=titer_limit)

titer_limit = {}
titer_limit[r_13PDO] = 100.0/76*1000*1.5
titer_limit[r_3HPP] = 100.0/90*1000*1.5
ecoli_pt150 = Ecoli(ecoli_model, id='ecoli_pt150', titer_limit=titer_limit) # product tolerance at 50%



## Setting up S. cerevisiae 
scere_model = pickle.load(open('models/scere_super.pickle','rb'))

# maximum titer of products are set to 75, 150, 225 g/L for S. cerevisiae
titer_limit = {}
titer_limit[r_13PDO] = 150.0/76*1000*0.5
titer_limit[r_3HPP] = 150.0/90*1000*0.5
scere_pt50 = Scerevisiae(scere_model, id='scere_pt50', titer_limit=titer_limit)

titer_limit = {}
titer_limit[r_13PDO] = 150.0/76*1000
titer_limit[r_3HPP] = 150.0/90*1000
scere_pt100 = Scerevisiae(scere_model, id='scere_pt100', titer_limit=titer_limit)

titer_limit = {}
titer_limit[r_13PDO] = 150.0/76*1000*1.5
titer_limit[r_3HPP] = 150.0/90*1000*1.5
scere_pt150 = Scerevisiae(scere_model, id='scere_pt150', titer_limit=titer_limit)
# Out:
# Biomass reaction detected: R_Ec_biomass_iJO1366_core_53p95M
# Biomass reaction detected: R_biomass_SC5_notrace

# %%
### Setting up a collection of in silico Bioreactors
from cbmTES.bioreactor import IdealFedbatch
from cbmTES.bioreactor import ecoli_parameters, scere_parameters

hosts = [ecoli_pt50, ecoli_pt100, ecoli_pt150, scere_pt50, scere_pt100, scere_pt150]
#hosts = [scere]
oxygen_availability = [AEROBIC, ANAEROBIC]
substrates = [r_glc, r_glyc]
product = [r_13PDO, r_3HPP]

# construct a bioreactor instance for each condition.
bioreactors = OrderedDict()

# host specific parameters
s_feed = {}
s_init = {}

for h in hosts:
    if 'ecoli' in h.id:
        s_feed[h.id, r_glc] = 500.0/180*1000 #Alves 2007
        s_init[h.id, r_glc] = 50.0/180*1000
        s_feed[h.id, r_glyc] = 500.0/92*1000
        s_init[h.id, r_glyc] = 100.0/92*1000
    if 'scere' in h.id:
        s_feed[h.id, r_glc] = 500.0/180*1000
        s_init[h.id, r_glc] = 200.0/180*1000
        s_feed[h.id, r_glyc] = 500.0/92*1000
        s_init[h.id, r_glyc] = 60.0/92*1000



conditions = [(h, o, s, p) for h in hosts for o in oxygen_availability for s in substrates for p in product if not (o == ANAEROBIC and s == r_glyc) ]

for condition in conditions:
    host = condition[0]
    oxygen_availability = condition[1]
    substrate = condition[2]
    product = condition[3]
    
    metabolites = [substrate, product]
    Sfeed = [s_feed[host.id, substrate], 0]
    bioreactors[host.id, oxygen_availability, substrate, product] = IdealFedbatch(metabolites=metabolites, Sfeed = Sfeed, volume_max=10, oxygen_availability=oxygen_availability)

    # initilize bioreactor
    Vinit = [1]
    Xinit = [0.01]
    Sinit = [s_init[host.id, substrate], 0]
    bioreactors[host.id,  oxygen_availability, substrate, product].set_initial_conditions(Vinit, Xinit, Sinit)

# %% [markdown]
# ### Dynamic Scanning Analysis

# %%
from collections import OrderedDict
from time import time
import framed.bioreactor.dyssco as dyssco
import cPickle as pickle

# make 10 strains along production envelopes for each case
strains = OrderedDict()

for condition in conditions:
    host = condition[0]
    oxygen_availability = condition[1]
    substrate = condition[2]
    product = condition[3]
    print host.id, ':', oxygen_availability, ':', substrate, ':', product
    t0 = time()
    if 'ecoli' in host.id:
        strains[host.id, oxygen_availability, substrate, product] = dyssco.make_envelope_strains(host, substrate, product, N=10, constraints=fba_constraints['ecoli', substrate, oxygen_availability])
    elif 'scere' in host.id:
        strains[host.id, oxygen_availability, substrate, product] = dyssco.make_envelope_strains(host, substrate, product, N=10, constraints=fba_constraints['scere', substrate, oxygen_availability])
    t1 = time()
    print 'Simulation runtime: ', t1-t0
    
pickle.dump(strains,  open('jar/strains_sa_pt.pickle','wb'))
# Out:
# ecoli_pt50 : 1 : R_EX_glc_e : R_EX_13PDO_e
# Biomass reaction detected: R_Ec_biomass_iJO1366_core_53p95M
# Simulation runtime:  15.6226460934
# ecoli_pt50 : 1 : R_EX_glc_e : R_EX_3HPP_e
# Simulation runtime:  14.2670099735
# ecoli_pt50 : 1 : R_EX_glyc_e : R_EX_13PDO_e
# Simulation runtime:  15.5430569649
# ecoli_pt50 : 1 : R_EX_glyc_e : R_EX_3HPP_e
# Simulation runtime:  14.6087241173
# ecoli_pt50 : 0 : R_EX_glc_e : R_EX_13PDO_e
# Simulation runtime:  16.2215499878
# ecoli_pt50 : 0 : R_EX_glc_e : R_EX_3HPP_e
# Simulation runtime:  15.3172669411
# ecoli_pt100 : 1 : R_EX_glc_e : R_EX_13PDO_e
# Simulation runtime:  14.1819210052
# ecoli_pt100 : 1 : R_EX_glc_e : R_EX_3HPP_e
# Simulation runtime:  17.9359710217
# ecoli_pt100 : 1 : R_EX_glyc_e : R_EX_13PDO_e
# Simulation runtime:  15.777310133
# ecoli_pt100 : 1 : R_EX_glyc_e : R_EX_3HPP_e
# Simulation runtime:  14.5785579681
# ecoli_pt100 : 0 : R_EX_glc_e : R_EX_13PDO_e
# Simulation runtime:  15.9727990627
# ecoli_pt100 : 0 : R_EX_glc_e : R_EX_3HPP_e
# Simulation runtime:  15.0187859535
# ecoli_pt150 : 1 : R_EX_glc_e : R_EX_13PDO_e
# Simulation runtime:  15.0012550354
# ecoli_pt150 : 1 : R_EX_glc_e : R_EX_3HPP_e
# Simulation runtime:  15.5554690361
# ecoli_pt150 : 1 : R_EX_glyc_e : R_EX_13PDO_e
# Simulation runtime:  16.1158909798
# ecoli_pt150 : 1 : R_EX_glyc_e : R_EX_3HPP_e
# Simulation runtime:  16.6276400089
# ecoli_pt150 : 0 : R_EX_glc_e : R_EX_13PDO_e
# Simulation runtime:  10.4744310379
# ecoli_pt150 : 0 : R_EX_glc_e : R_EX_3HPP_e
# Simulation runtime:  17.3026909828
# scere_pt50 : 1 : R_EX_glc_e : R_EX_13PDO_e
# Biomass reaction detected: R_biomass_SC5_notrace
# Simulation runtime:  14.5947868824
# scere_pt50 : 1 : R_EX_glc_e : R_EX_3HPP_e
# Simulation runtime:  7.57980704308
# scere_pt50 : 1 : R_EX_glyc_e : R_EX_13PDO_e
# Simulation runtime:  7.69730710983
# scere_pt50 : 1 : R_EX_glyc_e : R_EX_3HPP_e
# Simulation runtime:  15.0470778942
# scere_pt50 : 0 : R_EX_glc_e : R_EX_13PDO_e
# Simulation runtime:  7.27196192741
# scere_pt50 : 0 : R_EX_glc_e : R_EX_3HPP_e
# Simulation runtime:  7.28111505508
# scere_pt100 : 1 : R_EX_glc_e : R_EX_13PDO_e
# Simulation runtime:  15.2071049213
# scere_pt100 : 1 : R_EX_glc_e : R_EX_3HPP_e
# Simulation runtime:  6.5626718998
# scere_pt100 : 1 : R_EX_glyc_e : R_EX_13PDO_e
# Simulation runtime:  6.67937493324
# scere_pt100 : 1 : R_EX_glyc_e : R_EX_3HPP_e
# Simulation runtime:  15.8068702221
# scere_pt100 : 0 : R_EX_glc_e : R_EX_13PDO_e
# Simulation runtime:  8.14008593559
# scere_pt100 : 0 : R_EX_glc_e : R_EX_3HPP_e
# Simulation runtime:  9.58108282089
# scere_pt150 : 1 : R_EX_glc_e : R_EX_13PDO_e
# Simulation runtime:  8.54997205734
# scere_pt150 : 1 : R_EX_glc_e : R_EX_3HPP_e
# Simulation runtime:  17.0334010124
# scere_pt150 : 1 : R_EX_glyc_e : R_EX_13PDO_e
# Simulation runtime:  6.86190795898
# scere_pt150 : 1 : R_EX_glyc_e : R_EX_3HPP_e
# Simulation runtime:  6.6165201664
# scere_pt150 : 0 : R_EX_glc_e : R_EX_13PDO_e
# Simulation runtime:  17.9269249439
# scere_pt150 : 0 : R_EX_glc_e : R_EX_3HPP_e
# Simulation runtime:  6.67008304596

# %%
# simulate the metabolic activities of these strains using dynamic FBA
from collections import OrderedDict
from time import time
import framed.bioreactor.dyssco as dyssco
import cPickle as pickle

strains = pickle.load(open('jar/strains_sa_pt.pickle', 'rb'))

performances = OrderedDict()

dfba_solutions = {}

for condition in conditions:
    host = condition[0]
    oxygen_availability = condition[1]
    substrate = condition[2]
    product = condition[3]
    bioreactor=bioreactors[host.id, oxygen_availability, substrate, product]
    print host.id, ':', oxygen_availability, ':', substrate, ':', product
    t0 = time()
    strains_on_envelope = strains[host.id, oxygen_availability, substrate, product] # the 10 strains along the production envelop for a particular condition
    performance = dyssco.calculate_performances(strains_on_envelope, bioreactor, substrate, product, 0, 150, 0.2, verbose=False, additional_yields=['R_EX_co2_e', 'R_EX_nh4_e', 'R_EX_pi_e'], save_dfba_solution=True, dfba_solver='vode')
    t1 = time()
    print 'Simulation runtime: ', t1-t0
    performances[host.id, oxygen_availability, substrate, product] = performance
    
pickle.dump(performances,  open('jar/performances_sa_pt.pickle','wb'))
# Out:
# ecoli_pt50 : 1 : R_EX_glc_e : R_EX_13PDO_e
# Simulation runtime:  70.9107811451
# ecoli_pt50 : 1 : R_EX_glc_e : R_EX_3HPP_e
# Simulation runtime:  34.7460479736
# ecoli_pt50 : 1 : R_EX_glyc_e : R_EX_13PDO_e
# Simulation runtime:  54.6665148735
# ecoli_pt50 : 1 : R_EX_glyc_e : R_EX_3HPP_e
# Simulation runtime:  35.1159110069
# ecoli_pt50 : 0 : R_EX_glc_e : R_EX_13PDO_e
# Simulation runtime:  42.2022798061
# ecoli_pt50 : 0 : R_EX_glc_e : R_EX_3HPP_e
# Simulation runtime:  61.8976020813
# ecoli_pt100 : 1 : R_EX_glc_e : R_EX_13PDO_e
# Simulation runtime:  74.3679068089
# ecoli_pt100 : 1 : R_EX_glc_e : R_EX_3HPP_e
# Simulation runtime:  45.5624811649
# ecoli_pt100 : 1 : R_EX_glyc_e : R_EX_13PDO_e
# Simulation runtime:  73.0670130253
# ecoli_pt100 : 1 : R_EX_glyc_e : R_EX_3HPP_e
# Simulation runtime:  65.8404550552
# ecoli_pt100 : 0 : R_EX_glc_e : R_EX_13PDO_e
# Simulation runtime:  57.6475701332
# ecoli_pt100 : 0 : R_EX_glc_e : R_EX_3HPP_e
# Simulation runtime:  82.1435220242
# ecoli_pt150 : 1 : R_EX_glc_e : R_EX_13PDO_e
# Simulation runtime:  92.9077029228
# ecoli_pt150 : 1 : R_EX_glc_e : R_EX_3HPP_e
# Simulation runtime:  52.4560358524
# ecoli_pt150 : 1 : R_EX_glyc_e : R_EX_13PDO_e
# Simulation runtime:  88.7400410175
# ecoli_pt150 : 1 : R_EX_glyc_e : R_EX_3HPP_e
# Simulation runtime:  69.4753789902
# ecoli_pt150 : 0 : R_EX_glc_e : R_EX_13PDO_e
# Simulation runtime:  89.4442508221
# ecoli_pt150 : 0 : R_EX_glc_e : R_EX_3HPP_e
# Simulation runtime:  85.702947855
# scere_pt50 : 1 : R_EX_glc_e : R_EX_13PDO_e
# Simulation runtime:  36.7369258404
# scere_pt50 : 1 : R_EX_glc_e : R_EX_3HPP_e
# Simulation runtime:  39.0562958717
# scere_pt50 : 1 : R_EX_glyc_e : R_EX_13PDO_e
# Simulation runtime:  36.0524060726
# scere_pt50 : 1 : R_EX_glyc_e : R_EX_3HPP_e
# Simulation runtime:  46.6448130608
# scere_pt50 : 0 : R_EX_glc_e : R_EX_13PDO_e
# Simulation runtime:  45.1277160645
# scere_pt50 : 0 : R_EX_glc_e : R_EX_3HPP_e
# Simulation runtime:  45.7603797913
# scere_pt100 : 1 : R_EX_glc_e : R_EX_13PDO_e
# Simulation runtime:  63.1156039238
# scere_pt100 : 1 : R_EX_glc_e : R_EX_3HPP_e
# Simulation runtime:  50.8198280334
# scere_pt100 : 1 : R_EX_glyc_e : R_EX_13PDO_e
# Simulation runtime:  38.5946698189
# scere_pt100 : 1 : R_EX_glyc_e : R_EX_3HPP_e
# Simulation runtime:  35.6182141304
# scere_pt100 : 0 : R_EX_glc_e : R_EX_13PDO_e
# Simulation runtime:  80.2349979877
# scere_pt100 : 0 : R_EX_glc_e : R_EX_3HPP_e
# Simulation runtime:  53.3591148853
# scere_pt150 : 1 : R_EX_glc_e : R_EX_13PDO_e
# Simulation runtime:  76.0453009605
# scere_pt150 : 1 : R_EX_glc_e : R_EX_3HPP_e
# Simulation runtime:  69.821903944
# scere_pt150 : 1 : R_EX_glyc_e : R_EX_13PDO_e
# Simulation runtime:  76.2661659718
# scere_pt150 : 1 : R_EX_glyc_e : R_EX_3HPP_e
# Simulation runtime:  46.4140608311
# scere_pt150 : 0 : R_EX_glc_e : R_EX_13PDO_e
# Simulation runtime:  109.507918835
# scere_pt150 : 0 : R_EX_glc_e : R_EX_3HPP_e
# Simulation runtime:  72.1570379734
# /Users/kaizhuang/.virtualenvs/CfB/lib/python2.7/site-packages/framed/bioreactor/dyssco.py:216: RuntimeWarning: divide by zero encountered in double_scalars
#   performance['productivity'] = performance['product_titer']/dfba_solution['time'][index]

# %%
# convert the performance metric from mol-based to gram-based 
import cPickle as pickle
performances = pickle.load(open('jar/performances_sa_pt.pickle', 'rb'))

def convert_mmol2gram(performance, substrate, product, chemical_mass_table):
    """
    Unit conversion: mmol -> g 
        for Bioprocess A->B, convert the base unit of strain performance metric from mmol to gram.
        
        Product Yield(s): mmol/mmol -> g/g (x molar_mass_B / molar_mass_A)
        Biomass Yield: g/mmol -> g/g (x 1000/molar_mass_A)
        Productivity: mmol/L/hr -> g/L/hr (x molar_mass_B/1000)
        Titer: mmol/L -> g/L (x molar_mass_B/1000)
    """    
    MM_A = chemical_mass_table[substrate]  # molar mass of the substrate
    MM_B = chemical_mass_table[product]  # molar mass of the product
    converter = {'product_yield': MM_B / MM_A,
                 'biomass_yield': 1000/MM_A,   
                 'productivity': MM_B/1000,
                 'product_titer': MM_B/1000         
                 }
    
    for c_id, c_factor in converter.items():
        performance[c_id] = performance[c_id]*c_factor
        
    
chemical_mass_table = {
r_glc:  180.16,  # g/mol
r_glyc: 92.09,   # g/mol
r_13PDO:  76.09,   # g/mol
r_3HPP:  90.08   # g/mol
}

for key, performance in performances.items():
    for p in performance:
        convert_mmol2gram(p, key[2], key[3], chemical_mass_table)
        
        
pickle.dump(performances,  open('jar/performances_sa_pt.pickle','wb'))

# %% [markdown]
# ### Creating three Economy scale models with 50%, 100%, and 150% product tolerance

# %%
import cPickle as pickle
# from collections import OrderedDict
from cbmTES.global_constants import *
from framed.hack.ratio_constraint import *
import cbmTES.biochemical as biochemical
from framed.analysis.simulation import FBA, pFBA

performances = pickle.load(open('jar/performances_sa_pt.pickle', 'rb'))


# performances_pt50 = OrderedDict()
# performances_pt100 = OrderedDict()
# performances_pt150 = OrderedDict()

# for key in performances.keys():
#     if 'pt50' in key[0]:
#         performances_pt50[key] = performances[key]
#     elif 'pt100' in key[0]:
#         performances_pt100[key] = performances[key]
#     elif 'pt150' in key[0]:
#         performances_pt150[key] = performances[key]

# %%
# import the economy scale model
model = pickle.load(open('models/mini_BChI_model.pickle','rb'))

# remove the existing BioProcess Reactions 
for rxn in model.reactions:
    if 'BPR' in rxn:
        model.remove_reaction(rxn)
        
# Adding Bioprocesses to the model

for key in performances.keys():
    strains = performances[key]
    #strains = biochemical.get_strains_metric(metric)
    
    if key[1] == AEROBIC:
        bioreactor = 'aeroFB'
    elif key[1] == ANAEROBIC:
        bioreactor = 'anaeFB'
    
    if key[2] == r_glc:
        substrate = 'glc'
    elif key[2] == r_glyc:
        substrate = 'glyc'
        
    if key[3] == r_13PDO:
        product = '1,3pdo'
    if key[3] == r_3HPP:
        product = '3hp'

    for i, strain in enumerate(strains):
        if strain['product_yield']>0 and strain['biomass_yield']>0:
            if product == '3hp':
                biochemical.add_bioprocess_reaction(model, substrate, product, strain, bioreactor, 'ctrf', 'evapM', 1, neutralization='3hp_lime', process_energy_intensity=biochemical.Ei, compartment='bch')
            else:    
                biochemical.add_bioprocess_reaction(model, substrate, product, strain, bioreactor, 'ctrf', 'evapM', 1, process_energy_intensity=biochemical.Ei, compartment='bch')

# %% [markdown]
# ### Sensitivity Analysis: Scenario 1A, B, C, D

# %%
## Setting up scenario 1A, B, C, D

### Objective Functions ###
OBJs=OrderedDict()
MAX = True
MIN = False
OBJs['min_global_warming'] = ('EX_co2e_mkt', MIN) # minimize total global warming potential

### Flux Constraints ###
FCs = OrderedDict()
FCs['no import'] = {'DM_glyc_mkt':(0,0), 'DM_glc_mkt':(0,0), 'DM_energy_mkt':(0,0)}
FCs['product demand: 3hp = 1000']= {'DM_3hp_mkt':(1000,1000), 'DM_1,3pdo_mkt':(0,0)}
FCs['product demand: pdo = 1000']= {'DM_3hp_mkt':(0, 0), 'DM_1,3pdo_mkt':(1000,1000)}
FCs['product demand: 3hp = 500, pdo=500']= {'DM_3hp_mkt':(500,500), 'DM_1,3pdo_mkt':(500,500)}

FCs['positive profits']= {'PROFIT_res':(0,None), 'PROFIT_agr':(0,None), 'PROFIT_erg':(0,None), 'PROFIT_bch':(0,None)}
FCs['no biodiesel'] = {'energy_from_biodiesel':(0,0)}
FCs['land use < 1'] = {'EX_land_res':(-1,0)}
FCs['land use < 5'] = {'EX_land_res':(-5,0)}
FCs['co2 < 2000'] = {'EX_co2e_mkt':(0, 2000)}


### Ratio Constraints ###

# EU Energy Mix
def add_RC_EU_energy(model):
    add_ratio_constraint(model, 'energy_from_petroleum', 'MX_erg2mkt_energy', 0.25)
    add_ratio_constraint(model, 'energy_from_natural_gas', 'MX_erg2mkt_energy', 0.7)
    add_ratio_constraint(model, 'energy_from_coal', 'MX_erg2mkt_energy', 0.05)

def remove_RC_EU_energy(model):
    remove_ratio_constraint(model, 'ratio_energy_from_petroleum_MX_erg2mkt_energy')
    remove_ratio_constraint(model, 'ratio_energy_from_natural_gas_MX_erg2mkt_energy')
    remove_ratio_constraint(model, 'ratio_energy_from_coal_MX_erg2mkt_energy')

Scenarios = OrderedDict()
base_scenario = {k:v for d in (FCs['no import'], FCs['positive profits']) for k, v in d.iteritems()}
Scenarios['pdo1000, land<1, energy=EU'] = {k:v for d in (base_scenario, FCs['product demand: pdo = 1000'], FCs['land use < 1'], FCs['no biodiesel']) for k, v in d.iteritems()}

# %%
### Objective Functions ###
OBJs=OrderedDict()
MAX = True
MIN = False
OBJs['min_global_warming'] = ('EX_co2e_mkt', MIN) # minimize total global warming potential
OBJs['min_eutrofication'] = ('EX_po4e_mkt', MIN) # minimize total eutrophication potential
OBJs['max_bch_profit'] = ('PROFIT_bch', MAX) # maximize profit of biochemical industry
OBJs['min_bch_energy'] = ('MX_bch2mkt_energy', MAX) # minimize energy usage of biochemical industry

S = 'pdo1000, land<1, energy=EU'

if 'energy=EU' in S:
    add_RC_EU_energy(model)  # add EU energy mixing constraint

# %%
# sensitivity analysis
solutions = OrderedDict()
for pt in ['pt50','pt100','pt150']:
    for r in model.reactions:
        if 'BPR' in r:
            if pt in r:
                model.bounds[r] = (0, None)
            else:
                model.bounds[r] = (0, 0)
    for O in OBJs:
        print O
        solutions[O, S, pt] = FBA(model, objective={OBJs[O][0]:1}, maximize=OBJs[O][1], constraints = Scenarios[S])
# Out:
# min_global_warming
# min_eutrofication
# max_bch_profit
# min_bch_energy
# min_global_warming
# min_eutrofication
# max_bch_profit
# min_bch_energy
# min_global_warming
# min_eutrofication
# max_bch_profit
# min_bch_energy

# %%
for (O, S, k) in solutions:
    print O, ' -- ', k,': ', solutions[O, S, k].fobj
# Out:
# min_global_warming  --  pt50 :  -2501.86493062
# min_eutrofication  --  pt50 :  -9.81268005595
# max_bch_profit  --  pt50 :  565.658900232
# min_bch_energy  --  pt50 :  -19555.2239571
# min_global_warming  --  pt100 :  -1858.88205586
# min_eutrofication  --  pt100 :  -9.81268005595
# max_bch_profit  --  pt100 :  774.842570386
# min_bch_energy  --  pt100 :  -10022.7775533
# min_global_warming  --  pt150 :  -1618.45992487
# min_eutrofication  --  pt150 :  -9.81268005595
# max_bch_profit  --  pt150 :  853.352822845
# min_bch_energy  --  pt150 :  -7256.87859956

# %%
print model
# Out:
# EX_co2e_mkt: co2e_mkt <->
# EX_po4e_mkt: po4e_mkt <->
# EX_waste_organic_mkt: waste_organic_mkt <->
# EX_waste_cellulosic_mkt: waste_cellulosic_mkt <->
# EX_waste_inorganic_mkt: waste_inorganic_mkt <->
# EX_lime_mkt: lime_mkt <->
# EX_sulfuric_acid_mkt: sulfuric_acid_mkt <->
# DM_glc_mkt: glc_mkt <-> 0.43 dollar_mkt
# DM_glyc_mkt: glyc_mkt <-> 0.18 dollar_mkt
# DM_1,3pdo_mkt: 1,3pdo_mkt <-> 1.8 dollar_mkt
# DM_3hp_mkt: 3hp_mkt <-> 2.4 dollar_mkt
# DM_biomass_mkt: biomass_mkt <->
# DM_soymeal_mkt: soymeal_mkt <->
# DM_biodiesel_mkt: biodiesel_mkt <-> 0.9072 dollar_mkt
# DM_energy_mkt: energy_mkt <-> 0.02 dollar_mkt
# EX_land_res: land_res <->
# EX_petroleum_res: petroleum_res <->
# EX_natural_gas_res: natural_gas_res <->
# EX_coal_res: coal_res <->
# MX_res2mkt_land: land_res + 41 dollar_mkt <-> land_mkt + 41 dollar_res
# PROFIT_res: dollar_res <->
# MX_res2mkt_petroleum: petroleum_res + 0.765 dollar_mkt <-> petroleum_mkt + 0.765 dollar_res
# MX_res2mkt_natural_gas: natural_gas_res + 0.5628 dollar_mkt <-> natural_gas_mkt + 0.5628 dollar_res
# MX_res2mkt_coal: coal_res + 0.0552 dollar_mkt <-> coal_mkt + 0.0552 dollar_res
# MX_agr2mkt_land: land_agr + 41 dollar_mkt <-> land_mkt + 41 dollar_agr
# MX_agr2mkt_po4e: po4e_agr <-> po4e_mkt
# MX_agr2mkt_waste_organic: waste_organic_agr <-> waste_organic_mkt
# MX_agr2mkt_waste_cellulosic: waste_cellulosic_agr <-> waste_cellulosic_mkt
# MX_agr2mkt_glc: glc_agr + 0.43 dollar_mkt <-> glc_mkt + 0.43 dollar_agr
# MX_agr2mkt_glyc: glyc_agr + 0.18 dollar_mkt <-> glyc_mkt + 0.18 dollar_agr
# MX_agr2mkt_soymeal: soymeal_agr <-> soymeal_mkt
# MX_agr2mkt_biodiesel: biodiesel_agr + 0.9072 dollar_mkt <-> biodiesel_mkt + 0.9072 dollar_agr
# MX_agr2mkt_energy: energy_agr + 0.02 dollar_mkt <-> energy_mkt + 0.02 dollar_agr
# soy_conversion: 1.46768831169 energy_agr + soyoil_agr --> 0.96 biodiesel_agr + 0.205 glyc_agr
# PROFIT_agr: dollar_agr <->
# soy_crushing: soy_agr + 1.0668961039 energy_agr --> 0.18 soyoil_agr + 0.074 waste_cellulosic_agr + 0.574 soymeal_agr
# corn_farming: 0.000116959064327 land_agr + 2.75 energy_agr --> corn_agr + 0.0031072 po4e_agr
# corn_hydrolysis: starch_agr --> 0.95 glc_agr + 0.05 waste_organic_agr
# corn_wetmill: corn_agr + 2.17301775148 energy_agr --> 0.455621301775 waste_cellulosic_agr + 0.544378698225 starch_agr
# soy_farming: 0.00037037037037 land_agr + 2.13 energy_agr --> soy_agr + 0.0020772 po4e_agr
# MX_erg2mkt_petroleum: petroleum_erg + 0.765 dollar_mkt <-> petroleum_mkt + 0.765 dollar_erg
# MX_erg2mkt_natural_gas: natural_gas_erg + 0.5628 dollar_mkt <-> natural_gas_mkt + 0.5628 dollar_erg
# MX_erg2mkt_coal: coal_erg + 0.0552 dollar_mkt <-> coal_mkt + 0.0552 dollar_erg
# MX_erg2mkt_co2e: co2e_erg <-> co2e_mkt
# MX_erg2mkt_energy: energy_erg + 0.02 dollar_mkt + 0.5 ratio_energy_from_petroleum_MX_erg2mkt_energy + 1.4 ratio_energy_from_natural_gas_MX_erg2mkt_energy + 0.1 ratio_energy_from_coal_MX_erg2mkt_energy <-> energy_mkt + 0.02 dollar_erg
# MX_erg2mkt_biodiesel: biodiesel_erg + 0.9072 dollar_mkt <-> biodiesel_mkt + 0.9072 dollar_erg
# energy_from_natural_gas: 0.0186567164179 natural_gas_erg --> 0.057 co2e_erg + energy_erg + 2 ratio_energy_from_natural_gas_MX_erg2mkt_energy
# PROFIT_erg: dollar_erg <->
# energy_from_petroleum: 0.0235294117647 petroleum_erg --> 0.075 co2e_erg + energy_erg + 2 ratio_energy_from_petroleum_MX_erg2mkt_energy
# energy_from_coal: 0.0416666666667 coal_erg --> energy_erg + 0.095 co2e_erg + 2 ratio_energy_from_coal_MX_erg2mkt_energy
# energy_from_biodiesel: 0.026455026455 biodiesel_erg --> energy_erg + 0.049 co2e_erg
# MX_bch2mkt_land: land_bch + 41 dollar_mkt <-> land_mkt + 41 dollar_bch
# MX_bch2mkt_waste_organic: waste_organic_bch <-> waste_organic_mkt
# MX_bch2mkt_waste_inorganic: waste_inorganic_bch <-> waste_inorganic_mkt
# MX_bch2mkt_glc: glc_bch + 0.43 dollar_mkt <-> glc_mkt + 0.43 dollar_bch
# MX_bch2mkt_glyc: glyc_bch + 0.18 dollar_mkt <-> glyc_mkt + 0.18 dollar_bch
# MX_bch2mkt_1,3pdo: 1,3pdo_bch + 1.8 dollar_mkt <-> 1,3pdo_mkt + 1.8 dollar_bch
# MX_bch2mkt_3hp: 3hp_bch + 2.4 dollar_mkt <-> 3hp_mkt + 2.4 dollar_bch
# MX_bch2mkt_biomass: biomass_bch <-> biomass_mkt
# MX_bch2mkt_energy: energy_bch + 0.02 dollar_mkt <-> energy_mkt + 0.02 dollar_bch
# MX_bch2mkt_lime: lime_bch <-> lime_mkt
# MX_bch2mkt_sulfuric_acid: sulfuric_acid_bch <-> sulfuric_acid_mkt
# inorganicWaste_from_gypsum: gypsum_bch --> waste_inorganic_bch
# PROFIT_bch: dollar_bch <->
# BPR_glc_1,3pdo_ecoli_pt50_mu_0.1_aeroFB_ctrf_evapM: glc_bch + 34.6654433796 energy_bch --> 0.556441989448 1,3pdo_bch + 0.0554581265729 biomass_bch + 0.38809988398 waste_organic_bch [0, 0]
# BPR_glc_1,3pdo_ecoli_pt50_mu_0.2_aeroFB_ctrf_evapM: glc_bch + 23.3404189688 energy_bch --> 0.494329757811 1,3pdo_bch + 0.110916253146 biomass_bch + 0.394753989044 waste_organic_bch [0, 0]
# BPR_glc_1,3pdo_ecoli_pt50_mu_0.3_aeroFB_ctrf_evapM: glc_bch + 18.0300202784 energy_bch --> 0.432217526174 1,3pdo_bch + 0.166374379719 biomass_bch + 0.401408094108 waste_organic_bch [0, 0]
# BPR_glc_1,3pdo_ecoli_pt50_mu_0.4_aeroFB_ctrf_evapM: glc_bch + 14.3598378524 energy_bch --> 0.370105294537 1,3pdo_bch + 0.221832506292 biomass_bch + 0.408062199172 waste_organic_bch [0, 0]
# BPR_glc_1,3pdo_ecoli_pt50_mu_0.5_aeroFB_ctrf_evapM: glc_bch + 11.4173139372 energy_bch --> 0.3079930629 1,3pdo_bch + 0.277290632865 biomass_bch + 0.414716304236 waste_organic_bch [0, 0]
# BPR_glc_1,3pdo_ecoli_pt50_mu_0.599_aeroFB_ctrf_evapM: glc_bch + 8.84714197252 energy_bch --> 0.245760797135 1,3pdo_bch + 0.332748758799 biomass_bch + 0.421490444066 waste_organic_bch [0, 0]
# BPR_glc_1,3pdo_ecoli_pt50_mu_0.699_aeroFB_ctrf_evapM: glc_bch + 6.47518204984 energy_bch --> 0.183199720944 1,3pdo_bch + 0.388206885266 biomass_bch + 0.428593393791 waste_organic_bch [0, 0]
# BPR_glc_1,3pdo_ecoli_pt50_mu_0.799_aeroFB_ctrf_evapM: glc_bch + 4.29172874782 energy_bch --> 0.120296074161 1,3pdo_bch + 0.443665011732 biomass_bch + 0.436038914106 waste_organic_bch [0, 0]
# BPR_glc_3hp_ecoli_pt50_mu_0.1_aeroFB_ctrf_evapM: glc_bch + 54.070643214 energy_bch + 0.376300634955 lime_bch + 0.498074557913 sulfuric_acid_bch --> 0.914905506821 3hp_bch + 0.0554581265712 biomass_bch + 0.0296363666078 waste_organic_bch + 0.691394091505 gypsum_bch [0, 0]
# BPR_glc_3hp_ecoli_pt50_mu_0.2_aeroFB_ctrf_evapM: glc_bch + 37.0811380904 energy_bch + 0.334419904526 lime_bch + 0.442640885057 sulfuric_acid_bch --> 0.813080244411 3hp_bch + 0.110916253142 biomass_bch + 0.0760035024464 waste_organic_bch + 0.614444740702 gypsum_bch [0, 0]
# BPR_glc_3hp_ecoli_pt50_mu_0.3_aeroFB_ctrf_evapM: glc_bch + 28.8345257461 energy_bch + 0.292539174097 lime_bch + 0.387207212202 sulfuric_acid_bch --> 0.711254982001 3hp_bch + 0.166374379714 biomass_bch + 0.122370638285 waste_organic_bch + 0.537495389898 gypsum_bch [0, 0]
# BPR_glc_3hp_ecoli_pt50_mu_0.4_aeroFB_ctrf_evapM: glc_bch + 23.1219304913 energy_bch + 0.250658443668 lime_bch + 0.331773539346 sulfuric_acid_bch --> 0.609429719592 3hp_bch + 0.221832506285 biomass_bch + 0.168737774124 waste_organic_bch + 0.460546039095 gypsum_bch [0, 0]
# BPR_glc_3hp_ecoli_pt50_mu_0.5_aeroFB_ctrf_evapM: glc_bch + 18.4180367781 energy_bch + 0.20853579078 lime_bch + 0.276019655971 sulfuric_acid_bch --> 0.507016267396 3hp_bch + 0.277290632875 biomass_bch + 0.215693099728 waste_organic_bch + 0.383152193271 gypsum_bch [0, 0]
# BPR_glc_3hp_ecoli_pt50_mu_0.599_aeroFB_ctrf_evapM: glc_bch + 14.2849987659 energy_bch + 0.166207982314 lime_bch + 0.219994227016 sulfuric_acid_bch --> 0.404104017296 3hp_bch + 0.332748758799 biomass_bch + 0.263147223904 waste_organic_bch + 0.305381405871 gypsum_bch [0, 0]
# BPR_glc_3hp_ecoli_pt50_mu_0.699_aeroFB_ctrf_evapM: glc_bch +
waste_organic_bch
# BPR_glc_1,3pdo_ecoli_pt150_mu_0.403_anaeFB_ctrf_evapM: glc_bch + 3.28690454186 energy_bch --> 0.175884690695 1,3pdo_bch + 0.1117761792 biomass_bch + 0.712339130105 waste_organic_bch
# BPR_glc_1,3pdo_ecoli_pt150_mu_0.46_anaeFB_ctrf_evapM: glc_bch + 3.25724401475 energy_bch --> 0.0879428024329 1,3pdo_bch + 0.1277442048 biomass_bch + 0.784312992767 waste_organic_bch
# BPR_glc_3hp_ecoli_pt150_mu_0.058_anaeFB_ctrf_evapM: glc_bch + 11.9974742855 energy_bch + 0.402783399757 lime_bch + 0.533127359172 sulfuric_acid_bch --> 0.97929345917 3hp_bch + 0.0159680257765 biomass_bch + 0.00473851505314 waste_organic_bch + 0.740052067095 gypsum_bch
# BPR_glc_3hp_ecoli_pt150_mu_0.115_anaeFB_ctrf_evapM: glc_bch + 10.4431417985 energy_bch + 0.394266799514 lime_bch + 0.521854718345 sulfuric_acid_bch --> 0.958586918341 3hp_bch + 0.031936051553 biomass_bch + 0.00947703010627 waste_organic_bch + 0.72440413419 gypsum_bch
# BPR_glc_3hp_ecoli_pt150_mu_0.173_anaeFB_ctrf_evapM: glc_bch + 9.34919353476 energy_bch + 0.369522974227 lime_bch + 0.489103591464 sulfuric_acid_bch --> 0.898426876311 3hp_bch + 0.0479040768099 biomass_bch + 0.053669046879 waste_organic_bch + 0.678941190428 gypsum_bch
# BPR_glc_3hp_ecoli_pt150_mu_0.23_anaeFB_ctrf_evapM: glc_bch + 7.78750113636 energy_bch + 0.314981423969 lime_bch + 0.416911955285 sulfuric_acid_bch --> 0.765819168415 3hp_bch + 0.0638721024132 biomass_bch + 0.170308729172 waste_organic_bch + 0.578729545571 gypsum_bch
# BPR_glc_3hp_ecoli_pt150_mu_0.288_anaeFB_ctrf_evapM: glc_bch + 6.35041537941 energy_bch + 0.260439873711 lime_bch + 0.344720319106 sulfuric_acid_bch --> 0.633211460518 3hp_bch + 0.0798401280165 biomass_bch + 0.286948411465 waste_organic_bch + 0.478517900714 gypsum_bch
# BPR_glc_3hp_ecoli_pt150_mu_0.345_anaeFB_ctrf_evapM: glc_bch + 4.98149571423 energy_bch + 0.205898323453 lime_bch + 0.272528682928 sulfuric_acid_bch --> 0.500603752622 3hp_bch + 0.0958081536198 biomass_bch + 0.403588093758 waste_organic_bch + 0.378306255857 gypsum_bch
# BPR_glc_3hp_ecoli_pt150_mu_0.403_anaeFB_ctrf_evapM: glc_bch + 3.4916151606 energy_bch + 0.144109601141 lime_bch + 0.190744631319 sulfuric_acid_bch --> 0.350375884127 3hp_bch + 0.111776179197 biomass_bch + 0.537847936676 waste_organic_bch + 0.264779055635 gypsum_bch
# BPR_glc_3hp_ecoli_pt150_mu_0.46_anaeFB_ctrf_evapM: glc_bch + 3.25723889784 energy_bch + 0.0729376155903 lime_bch + 0.0965408167453 sulfuric_acid_bch --> 0.177334343764 3hp_bch + 0.127744204796 biomass_bch + 0.694921451439 waste_organic_bch + 0.134011563583 gypsum_bch
# BPR_glc_3hp_ecoli_pt150_mu_0.518_anaeFB_ctrf_evapM: glc_bch + 3.23152314884 energy_bch + 0.00176488815532 lime_bch + 0.00233602020851 sulfuric_acid_bch --> 0.00429099964825 3hp_bch + 0.143712231989 biomass_bch + 0.851996768363 waste_organic_bch + 0.00324270843418 gypsum_bch
# BPR_glc_1,3pdo_scere_pt50_mu_0.079_aeroFB_ctrf_evapM: glc_bch + 27.6771656804 energy_bch --> 0.612289541567 1,3pdo_bch + 0.0219542583098 biomass_bch + 0.365756200123 waste_organic_bch [0, 0]
# BPR_glc_1,3pdo_scere_pt50_mu_0.158_aeroFB_ctrf_evapM: glc_bch + 19.6493184767 energy_bch --> 0.591977024094 1,3pdo_bch + 0.0439085166197 biomass_bch + 0.364114459286 waste_organic_bch [0, 0]
# BPR_glc_1,3pdo_scere_pt50_mu_0.237_aeroFB_ctrf_evapM: glc_bch + 16.4257707799 energy_bch --> 0.571664506622 1,3pdo_bch + 0.0658627749295 biomass_bch + 0.362472718449 waste_organic_bch [0, 0]
# BPR_glc_1,3pdo_scere_pt50_mu_0.316_aeroFB_ctrf_evapM: glc_bch + 14.4284224721 energy_bch --> 0.545933741251 1,3pdo_bch + 0.0878170332394 biomass_bch + 0.366249225509 waste_organic_bch [0, 0]
# BPR_glc_1,3pdo_scere_pt50_mu_0.396_aeroFB_ctrf_evapM: glc_bch + 12.9879671976 energy_bch --> 0.519656891189 1,3pdo_bch + 0.109771291549 biomass_bch + 0.370571817261 waste_organic_bch [0, 0]
# BPR_glc_1,3pdo_scere_pt50_mu_0.475_aeroFB_ctrf_evapM: glc_bch + 10.3835817298 energy_bch --> 0.429027995203 1,3pdo_bch + 0.131725549859 biomass_bch + 0.439246454938 waste_organic_bch [0, 0]
# BPR_glc_1,3pdo_scere_pt50_mu_0.554_aeroFB_ctrf_evapM: glc_bch + 6.98434880462 energy_bch --> 0.286018663469 1,3pdo_bch + 0.153679808169 biomass_bch + 0.560301528362 waste_organic_bch [0, 0]
# BPR_glc_1,3pdo_scere_pt50_mu_0.633_aeroFB_ctrf_evapM: glc_bch + 3.86006548163 energy_bch --> 0.143009331734 1,3pdo_bch + 0.175634066479 biomass_bch + 0.681356601787 waste_organic_bch [0, 0]
# BPR_glc_3hp_scere_pt50_mu_0.079_aeroFB_ctrf_evapM: glc_bch + 40.4573537629 energy_bch + 0.393702182602 lime_bch + 0.521107386842 sulfuric_acid_bch --> 0.957214156581 3hp_bch + 0.0219542583098 biomass_bch + 0.0208315851096 waste_organic_bch + 0.723366738128 gypsum_bch [0, 0]
# BPR_glc_3hp_scere_pt50_mu_0.158_aeroFB_ctrf_evapM: glc_bch + 29.1360697429 energy_bch + 0.37727950806 lime_bch + 0.499370202256 sulfuric_acid_bch --> 0.917285456018 3hp_bch + 0.0439085166197 biomass_bch + 0.038806027362 waste_organic_bch + 0.693192619113 gypsum_bch [0, 0]
# BPR_glc_3hp_scere_pt50_mu_0.237_aeroFB_ctrf_evapM: glc_bch + 24.3950045164 energy_bch + 0.360856833519 lime_bch + 0.47763301767 sulfuric_acid_bch --> 0.877356755456 3hp_bch + 0.0658627749295 biomass_bch + 0.0567804696144 waste_organic_bch + 0.663018500098 gypsum_bch [0, 0]
# BPR_glc_3hp_scere_pt50_mu_0.316_aeroFB_ctrf_evapM: glc_bch + 21.4793580006 energy_bch + 0.344434158978 lime_bch + 0.455895833084 sulfuric_acid_bch --> 0.837428054894 3hp_bch + 0.0878170332394 biomass_bch + 0.0747549118669 waste_organic_bch + 0.632844381083 gypsum_bch [0, 0]
# BPR_glc_3hp_scere_pt50_mu_0.396_aeroFB_ctrf_evapM: glc_bch + 16.7121720873 energy_bch + 0.27975973316 lime_bch + 0.370292241022 sulfuric_acid_bch --> 0.680184131194 3hp_bch + 0.109771291549 biomass_bch + 0.210044577257 waste_organic_bch + 0.514015147943 gypsum_bch [0, 0]
# BPR_glc_3hp_scere_pt50_mu_0.475_aeroFB_ctrf_evapM: glc_bch + 12.2525623594 energy_bch + 0.210813579792 lime_bch + 0.279034555893 sulfuric_acid_bch --> 0.512554290766 3hp_bch + 0.131725549859 biomass_bch + 0.355720159375 waste_organic_bch + 0.387337277532 gypsum_bch [0, 0]
# BPR_glc_3hp_scere_pt50_mu_0.554_aeroFB_ctrf_evapM: glc_bch + 8.2018698131 energy_bch + 0.141867426424 lime_bch + 0.187776870764 sulfuric_acid_bch --> 0.344924450339 3hp_bch + 0.153679808169 biomass_bch + 0.501395741493 waste_organic_bch + 0.260659407121 gypsum_bch [0, 0]
# BPR_glc_3hp_scere_pt50_mu_0.633_aeroFB_ctrf_evapM: glc_bch + 4.26695294458 energy_bch + 0.0729212730563 lime_bch + 0.0965191856354 sulfuric_acid_bch --> 0.177294609911 3hp_bch + 0.175634066479 biomass_bch + 0.647071323611 waste_organic_bch + 0.13398153671 gypsum_bch [0, 0]
# BPR_glc_3hp_scere_pt50_mu_0.712_aeroFB_ctrf_evapM: glc_bch + 2.82476906098 energy_bch + 3.78476491651e-05 lime_bch + 5.00954539399e-05 sulfuric_acid_bch --> 9.20195700586e-05 3hp_bch + 0.197588324789 biomass_bch + 0.802319655641 waste_organic_bch + 6.95391890933e-05 gypsum_bch [0, 0]
# BPR_glyc_1,3pdo_scere_pt50_mu_0.027_aeroFB_ctrf_evapM: glyc_bch + 658.200870799 energy_bch --> 0.642407047469 1,3pdo_bch + 0.0644008372188 biomass_bch + 0.293192115312 waste_organic_bch [0, 0]
# BPR_glyc_1,3pdo_scere_pt50_mu_0.053_aeroFB_ctrf_evapM: glyc_bch + 39.5540946099 energy_bch --> 0.562106166536 1,3pdo_bch + 0.128801674438 biomass_bch + 0.309092159027 waste_organic_bch [0, 0]
# BPR_glyc_1,3pdo_scere_pt50_mu_0.08_aeroFB_ctrf_evapM: glyc_bch + 26.8009935681 energy_bch --> 0.481805285602 1,3pdo_bch + 0.193202511656 biomass_bch + 0.324992202742 waste_organic_bch [0, 0]
# BPR_glyc_1,3pdo_scere_pt50_mu_0.107_aeroFB_ctrf_evapM: glyc_bch + 19.3326847541 energy_bch --> 0.401504404668 1,3pdo_bch + 0.257603348875 biomass_bch + 0.340892246456 waste_organic_bch [0, 0]
# BPR_glyc_1,3pdo_scere_pt50_mu_0.133_aeroFB_ctrf_evapM: glyc_bch + 14.057104603 energy_bch --> 0.321203523735 1,3pdo_bch + 0.322004186094 biomass_bch + 0.356792290171 waste_organic_bch [0, 0]
# BPR_glyc_1,3pdo_scere_pt50_mu_0.16_aeroFB_ctrf_evapM: glyc_bch + 10.0055397409 energy_bch --> 0.240902642801 1,3pdo_bch + 0.386405023313 biomass_bch + 0.372692333886 waste_organic_bch [0, 0]
# BPR_glyc_1,3pdo_scere_pt50_mu_0.187_aeroFB_ctrf_evapM: glyc_bch + 6.78330902059 energy_bch --> 0.160601761867 1,3pdo_bch + 0.450805860532 biomass_bch + 0.388592377601 waste_organic_bch [0, 0]
# BPR_glyc_1,3pdo_scere_pt50_mu_0.214_aeroFB_ctrf_evapM: glyc_bch + 6.33377155996 energy_bch --> 0.0803008809336 1,3pdo_bch + 0.515206697751 biomass_bch + 0.404492421316 waste_organic_bch [0, 0]
# BPR_glyc_3hp_scere_pt50_mu_0.027_aeroFB_ctrf_evapM: glyc_bch + 659.683703866 energy_bch + 0.373736339504 lime_bch + 0.494680435755 sulfuric_acid_bch --> 0.90867089595 3hp_bch + 0.0644008372188 biomass_bch + 0.0269282668315 waste_organic_bch + 0.686682596069 gypsum_bch [0, 0]
# BPR_glyc_3hp_scere_pt50_mu_0.053_aeroFB_ctrf_evapM: glyc_bch + 55.9094155368 energy_bch + 0.344272637191 lime_bch + 0.455682041543 sulfuric_acid_bch --> 0.837035344495 3hp_bch + 0.128801674438 biomass_bch + 0.0341629810672 waste_organic_bch + 0.632547609835 gypsum_bch [0, 0]
# BPR_glyc_3hp_scere_pt50_mu_0.08_aeroFB_ctrf_evapM: glyc_bch + 38.3041903963 energy_bch + 0.29701299979 lime_bch + 0.393128804002 sulfuric_acid_bch --> 0.722132263045 3hp_bch + 0.193202511656 biomass_bch + 0.0846652252987 waste_organic_bch + 0.545715351183 gypsum_bch [0, 0]
# BPR_glyc_3hp_scere_pt50_mu_0.107_aeroFB_ctrf_evapM: glyc_bch + 27.7413861363 energy_bch + 0.248073245231 lime_bch + 0.328351749827 sulfuric_acid_bch --> 0.60314428697 3hp_bch + 0.257603348875 biomass_bch + 0.139252364155 waste_organic_bch + 0.455796137663 gypsum_bch [0, 0]
# BPR_glyc_3hp_scere_pt50_mu_0.133_aeroFB_ctrf_evapM: glyc_bch + 20.2499951502 energy_bch + 0.199133490671 lime_bch + 0.263574695651 sulfuric_acid_bch --> 0.484156310895 3hp_bch + 0.322004186094 biomass_bch + 0.193839503011 waste_organic_bch + 0.365876924144 gypsum_bch [0, 0]
# BPR_glyc_3hp_scere_pt50_mu_0.16_aeroFB_ctrf_evapM: glyc_bch + 14.3540937087 energy_bch + 0.150193736112 lime_bch + 0.198797641476 sulfuric_acid_bch --> 0.365168334821 3hp_bch + 0.386405023313 biomass_bch + 0.248426641866 waste_organic_bch + 0.275957710624 gypsum_bch [0, 0]
# BPR_glyc_3hp_scere_pt50_mu_0.187_aeroFB_ctrf_evapM: glyc_bch + 9.36874820462 energy_bch + 0.100398837694 lime_bch + 0.132888711988 sulfuric_acid_bch --> 0.244101234365 3hp_bch + 0.450805860532 biomass_bch + 0.305092905103 waste_organic_bch + 0.18446730281 gypsum_bch [0, 0]
# BPR_glyc_3hp_scere_pt50_mu_0.214_aeroFB_ctrf_evapM: glyc_bch + 6.33378822217 energy_bch + 0.0502135695175 lime_bch + 0.0664630859357 sulfuric_acid_bch --> 0.122085021924 3hp_bch + 0.515206697751 biomass_bch + 0.362708280325 waste_organic_bch + 0.0922596510683 gypsum_bch [0, 0]
# BPR_glc_1,3pdo_scere_pt50_mu_0.048_anaeFB_ctrf_evapM: glc_bch + 14.4313083703 energy_bch --> 0.581902556632 1,3pdo_bch + 0.0132142046136 biomass_bch + 0.404883238755 waste_organic_bch [0, 0]
# BPR_glc_1,3pdo_scere_pt50_mu_0.095_anaeFB_ctrf_evapM: glc_bch + 11.7138384935 energy_bch --> 0.538071928178 1,3pdo_bch + 0.0264284092271 biomass_bch + 0.435499662595 waste_organic_bch [0, 0]
# BPR_glc_1,3pdo_scere_pt50_mu_0.143_anaeFB_ctrf_evapM: glc_bch + 10.1996479076 energy_bch --> 0.494241299725 1,3pdo_bch + 0.0396426138407 biomass_bch + 0.466116086435 waste_organic_bch [0, 0]
# BPR_glc_1,3pdo_scere_pt50_mu_0.19_anaeFB_ctrf_evapM: glc_bch + 9.03007585457 energy_bch --> 0.450290104848 1,3pdo_bch + 0.0528568184542 biomass_bch + 0.496853076697 waste_organic_bch [0, 0]
# BPR_glc_1,3pdo_scere_pt50_mu_0.238_anaeFB_ctrf_evapM: glc_bch + 7.93506498195 energy_bch --> 0.402866173872 1,3pdo_bch + 0.0660710230678 biomass_bch + 0.53106280306 waste_organic_bch [0, 0]
# BPR_glc_1,3pdo_scere_pt50_mu_0.286_anaeFB_ctrf_evapM: glc_bch + 6.20478243106 energy_bch --> 0.317222135549 1,3pdo_bch + 0.0792852276813 biomass_bch + 0.60349263677 waste_organic_bch [0, 0]
# BPR_glc_1,3pdo_scere_pt50_mu_0.333_anaeFB_ctrf_evapM: glc_bch + 4.5113595903 energy_bch --> 0.231149809813 1,3pdo_bch + 0.0924994322949 biomass_bch + 0.676350757893 waste_organic_bch [0, 0]
# BPR_glc_1,3pdo_scere_pt50_mu_0.381_anaeFB_ctrf_evapM: glc_bch + 3.0969667943 energy_bch --> 0.144858239412 1,3pdo_bch + 0.105713636908 biomass_bch + 0.74942812368 waste_organic_bch [0, 0]
# BPR_glc_1,3pdo_scere_pt50_mu_0.429_anaeFB_ctrf_evapM: glc_bch + 3.07015884364 energy_bch --> 0.0143822823784 1,3pdo_bch + 0.118927841522 biomass_bch + 0.8666898761 waste_organic_bch [0, 0]
# ...
# BPR_glc_1,3pdo_scere_pt100_mu_0.048_anaeFB_ctrf_evapM: glc_bch + 8.6709533443 energy_bch --> 0.581902556632 1,3pdo_bch + 0.0132142046136 biomass_bch + 0.404883238755 waste_organic_bch [0, 0]
# BPR_glc_1,3pdo_scere_pt100_mu_0.095_anaeFB_ctrf_evapM: glc_bch + 6.25688210218 energy_bch --> 0.538071928178 1,3pdo_bch + 0.0264284092271 biomass_bch + 0.435499662595 waste_organic_bch [0, 0]
# BPR_glc_1,3pdo_scere_pt100_mu_0.143_anaeFB_ctrf_evapM: glc_bch + 5.33842279301 energy_bch --> 0.494241299725 1,3pdo_bch + 0.0396426138407 biomass_bch + 0.466116086435 waste_organic_bch [0, 0]
# BPR_glc_1,3pdo_scere_pt100_mu_0.19_anaeFB_ctrf_evapM: glc_bch + 4.66947928206 energy_bch --> 0.450290104848 1,3pdo_bch + 0.0528568184542 biomass_bch + 0.496853076697 waste_organic_bch [0, 0]
# BPR_glc_1,3pdo_scere_pt100_mu_0.238_anaeFB_ctrf_evapM: glc_bch + 4.07144635262 energy_bch --> 0.402866173872 1,3pdo_bch + 0.0660710230678 biomass_bch + 0.53106280306 waste_organic_bch [0, 0]
# BPR_glc_1,3pdo_scere_pt100_mu_0.286_anaeFB_ctrf_evapM: glc_bch + 3.17944689959 energy_bch --> 0.317222135549 1,3pdo_bch + 0.0792852276813 biomass_bch + 0.60349263677 waste_organic_bch [0, 0]
# BPR_glc_1,3pdo_scere_pt100_mu_0.333_anaeFB_ctrf_evapM: glc_bch + 3.13343237204 energy_bch --> 0.231149809813 1,3pdo_bch + 0.0924994322949 biomass_bch + 0.676350757893 waste_organic_bch [0, 0]
# BPR_glc_1,3pdo_scere_pt100_mu_0.381_anaeFB_ctrf_evapM: glc_bch + 3.0969667943 energy_bch --> 0.144858239412 1,3pdo_bch + 0.105713636908 biomass_bch + 0.74942812368 waste_organic_bch [0, 0]
# BPR_glc_1,3pdo_scere_pt100_mu_0.429_anaeFB_ctrf_evapM: glc_bch + 3.07015884364 energy_bch --> 0.0143822823784 1,3pdo_bch + 0.118927841522 biomass_bch + 0.8666898761 waste_organic_bch [0, 0]
# BPR_glc_3hp_scere_pt100_mu_0.048_anaeFB_ctrf_evapM: glc_bch + 11.1413897557 energy_bch + 0.358655890265 lime_bch + 0.474719831413 sulfuric_acid_bch --> 0.872005568357 3hp_bch + 0.0132142046136 biomass_bch + 0.11478022703 waste_organic_bch + 0.658974608007 gypsum_bch [0, 0]
# BPR_glc_3hp_scere_pt100_mu_0.095_anaeFB_ctrf_evapM: glc_bch + 8.50105217813 energy_bch + 0.31410924928 lime_bch + 0.415757537827 sulfuric_acid_bch --> 0.763698636714 3hp_bch + 0.0264284092271 biomass_bch + 0.209872954059 waste_organic_bch + 0.577127059765 gypsum_bch [0, 0]
# BPR_glc_3hp_scere_pt100_mu_0.143_anaeFB_ctrf_evapM: glc_bch + 6.92356835682 energy_bch + 0.269562608296 lime_bch + 0.35679524424 sulfuric_acid_bch --> 0.655391705071 3hp_bch + 0.0396426138407 biomass_bch + 0.304965681089 waste_organic_bch + 0.495279511522 gypsum_bch [0, 0]
# BPR_glc_3hp_scere_pt100_mu_0.19_anaeFB_ctrf_evapM: glc_bch + 5.6584387638 energy_bch + 0.225015967311 lime_bch + 0.297832950654 sulfuric_acid_bch --> 0.547084773427 3hp_bch + 0.0528568184542 biomass_bch + 0.400058408118 waste_organic_bch + 0.413431963279 gypsum_bch [0, 0]
# BPR_glc_3hp_scere_pt100_mu_0.238_anaeFB_ctrf_evapM: glc_bch + 4.42954713322 energy_bch + 0.180433808956 lime_bch + 0.238823645989 sulfuric_acid_bch --> 0.438691487857 3hp_bch + 0.0660710230678 biomass_bch + 0.495237489075 waste_organic_bch + 0.331519157374 gypsum_bch [0, 0]
# BPR_glc_3hp_scere_pt100_mu_0.286_anaeFB_ctrf_evapM: glc_bch + 3.27490208918 energy_bch + 0.135572811927 lime_bch + 0.179445268206 sulfuric_acid_bch --> 0.329620257542 3hp_bch + 0.0792852276813 biomass_bch + 0.591094514777 waste_organic_bch + 0.249094028625 gypsum_bch [0, 0]
# BPR_glc_3hp_scere_pt100_mu_0.333_anaeFB_ctrf_evapM: glc_bch + 3.13344137505 energy_bch + 0.0903894680816 lime_bch + 0.119640229574 sulfuric_acid_bch --> 0.219765300466 3hp_bch + 0.0924994322949 biomass_bch + 0.687735267239 waste_organic_bch + 0.166076637562 gypsum_bch [0, 0]
# BPR_glc_3hp_scere_pt100_mu_0.381_anaeFB_ctrf_evapM: glc_bch + 3.09700330653 energy_bch + 0.0452061242361 lime_bch + 0.0598351909413 sulfuric_acid_bch --> 0.10991034339 3hp_bch + 0.105713636908 biomass_bch + 0.784376019702 waste_organic_bch + 0.0830592464995 gypsum_bch [0, 0]
# BPR_glc_3hp_scere_pt100_mu_0.429_anaeFB_ctrf_evapM: glc_bch + 2.82476856892 energy_bch + 2.27803906333e-05 lime_bch + 3.01523089248e-05 sulfuric_acid_bch --> 5.53863132344e-05 3hp_bch + 0.118927841522 biomass_bch + 0.881016772165 waste_organic_bch + 4.18554369113e-05 gypsum_bch [0, 0]
# BPR_glc_1,3pdo_scere_pt150_mu_0.079_aeroFB_ctrf_evapM: glc_bch + 11.8383534207 energy_bch --> 0.612289541567 1,3pdo_bch + 0.0219542583098 biomass_bch + 0.365756200123 waste_organic_bch
# BPR_glc_1,3pdo_scere_pt150_mu_0.158_aeroFB_ctrf_evapM: glc_bch + 7.82691851488 energy_bch --> 0.591977024094 1,3pdo_bch + 0.0439085166197 biomass_bch + 0.364114459286 waste_organic_bch
# BPR_glc_1,3pdo_scere_pt150_mu_0.237_aeroFB_ctrf_evapM: glc_bch + 6.2976862353 energy_bch --> 0.571664506622 1,3pdo_bch + 0.0658627749295 biomass_bch + 0.362472718449 waste_organic_bch
# BPR_glc_1,3pdo_scere_pt150_mu_0.316_aeroFB_ctrf_evapM: glc_bch + 5.38602811991 energy_bch --> 0.545933741251 1,3pdo_bch + 0.0878170332394 biomass_bch + 0.366249225509 waste_organic_bch
# BPR_glc_1,3pdo_scere_pt150_mu_0.396_aeroFB_ctrf_evapM: glc_bch + 4.75291143142 energy_bch --> 0.519656891189 1,3pdo_bch + 0.109771291549 biomass_bch + 0.370571817261 waste_organic_bch
# BPR_glc_1,3pdo_scere_pt150_mu_0.475_aeroFB_ctrf_evapM: glc_bch + 4.17057853374 energy_bch --> 0.429027995203 1,3pdo_bch + 0.131725549859 biomass_bch + 0.439246454938 waste_organic_bch
# BPR_glc_1,3pdo_scere_pt150_mu_0.554_aeroFB_ctrf_evapM: glc_bch + 3.98636977655 energy_bch --> 0.286018663469 1,3pdo_bch + 0.153679808169 biomass_bch + 0.560301528362 waste_organic_bch
# BPR_glc_1,3pdo_scere_pt150_mu_0.633_aeroFB_ctrf_evapM: glc_bch + 3.86006548163 energy_bch --> 0.143009331734 1,3pdo_bch + 0.175634066479 biomass_bch + 0.681356601787 waste_organic_bch
# BPR_glc_3hp_scere_pt150_mu_0.079_aeroFB_ctrf_evapM: glc_bch + 16.8136773337 energy_bch + 0.393702182602 lime_bch + 0.521107386842 sulfuric_acid_bch --> 0.957214156581 3hp_bch + 0.0219542583098 biomass_bch + 0.0208315851096 waste_organic_bch + 0.723366738128 gypsum_bch
# BPR_glc_3hp_scere_pt150_mu_0.158_aeroFB_ctrf_evapM: glc_bch + 11.4273800451 energy_bch + 0.37727950806 lime_bch + 0.499370202256 sulfuric_acid_bch --> 0.917285456018 3hp_bch + 0.0439085166197 biomass_bch + 0.038806027362 waste_organic_bch + 0.693192619113 gypsum_bch
# BPR_glc_3hp_scere_pt150_mu_0.237_aeroFB_ctrf_evapM: glc_bch + 9.31040860607 energy_bch + 0.360856833519 lime_bch + 0.47763301767 sulfuric_acid_bch --> 0.877356755456 3hp_bch + 0.0658627749295 biomass_bch + 0.0567804696144 waste_organic_bch + 0.663018500098 gypsum_bch
# BPR_glc_3hp_scere_pt150_mu_0.316_aeroFB_ctrf_evapM: glc_bch + 8.12370367644 energy_bch + 0.344434158978 lime_bch + 0.455895833084 sulfuric_acid_bch --> 0.837428054894 3hp_bch + 0.0878170332394 biomass_bch + 0.0747549118669 waste_organic_bch + 0.632844381083 gypsum_bch
# BPR_glc_3hp_scere_pt150_mu_0.396_aeroFB_ctrf_evapM: glc_bch + 6.1742026136 energy_bch + 0.27975973316 lime_bch + 0.370292241022 sulfuric_acid_bch --> 0.680184131194 3hp_bch + 0.109771291549 biomass_bch + 0.210044577257 waste_organic_bch + 0.514015147943 gypsum_bch
# BPR_glc_3hp_scere_pt150_mu_0.475_aeroFB_ctrf_evapM: glc_bch + 4.44372676384 energy_bch + 0.210813579792 lime_bch + 0.279034555893 sulfuric_acid_bch --> 0.512554290766 3hp_bch + 0.131725549859 biomass_bch + 0.355720159375 waste_organic_bch + 0.387337277532 gypsum_bch
# BPR_glc_3hp_scere_pt150_mu_0.554_aeroFB_ctrf_evapM: glc_bch + 3.98643509441 energy_bch + 0.141867426424 lime_bch + 0.187776870764 sulfuric_acid_bch --> 0.344924450339 3hp_bch + 0.153679808169 biomass_bch + 0.501395741493 waste_organic_bch + 0.260659407121 gypsum_bch
# BPR_glc_3hp_scere_pt150_mu_0.633_aeroFB_ctrf_evapM: glc_bch + 3.86005872572 energy_bch + 0.0729212730563 lime_bch + 0.0965191856354 sulfuric_acid_bch --> 0.177294609911 3hp_bch + 0.175634066479 biomass_bch + 0.647071323611 waste_organic_bch + 0.13398153671 gypsum_bch
# BPR_glc_3hp_scere_pt150_mu_0.712_aeroFB_ctrf_evapM: glc_bch + 2.82476906098 energy_bch + 3.78476491651e-05 lime_bch + 5.00954539399e-05 sulfuric_acid_bch --> 9.20195700586e-05 3hp_bch + 0.197588324789 biomass_bch + 0.802319655641 waste_organic_bch + 6.95391890933e-05 gypsum_bch
# BPR_glyc_1,3pdo_scere_pt150_mu_0.027_aeroFB_ctrf_evapM: glyc_bch + 658.200870799 energy_bch --> 0.642407047469 1,3pdo_bch + 0.0644008372188 biomass_bch + 0.293192115312 waste_organic_bch
# BPR_glyc_1,3pdo_scere_pt150_mu_0.053_aeroFB_ctrf_evapM: glyc_bch + 35.4072489831 energy_bch --> 0.562106166536 1,3pdo_bch + 0.128801674438 biomass_bch + 0.309092159027 waste_organic_bch
# BPR_glyc_1,3pdo_scere_pt150_mu_0.08_aeroFB_ctrf_evapM: glyc_bch + 11.3255841555 energy_bch --> 0.481805285602 1,3pdo_bch + 0.193202511656 biomass_bch + 0.324992202742 waste_organic_bch
# BPR_glyc_1,3pdo_scere_pt150_mu_0.107_aeroFB_ctrf_evapM: glyc_bch + 9.3856180221 energy_bch --> 0.401504404668 1,3pdo_bch + 0.257603348875 biomass_bch + 0.340892246456 waste_organic_bch
# BPR_glyc_1,3pdo_scere_pt150_mu_0.133_aeroFB_ctrf_evapM: glyc_bch + 8.17906155444 energy_bch --> 0.321203523735 1,3pdo_bch + 0.322004186094 biomass_bch + 0.356792290171 waste_organic_bch
# BPR_glyc_1,3pdo_scere_pt150_mu_0.16_aeroFB_ctrf_evapM: glyc_bch + 7.37470247741 energy_bch --> 0.240902642801 1,3pdo_bch + 0.386405023313 biomass_bch + 0.372692333886 waste_organic_bch
# BPR_glyc_1,3pdo_scere_pt150_mu_0.187_aeroFB_ctrf_evapM: glyc_bch + 6.78330902059 energy_bch --> 0.160601761867 1,3pdo_bch + 0.450805860532 biomass_bch + 0.388592377601 waste_organic_bch
# BPR_glyc_1,3pdo_scere_pt150_mu_0.214_aeroFB_ctrf_evapM: glyc_bch + 6.33377155996 energy_bch --> 0.0803008809336 1,3pdo_bch + 0.515206697751 biomass_bch + 0.404492421316 waste_organic_bch
# BPR_glyc_3hp_scere_pt150_mu_0.027_aeroFB_ctrf_evapM: glyc_bch + 659.683703866 energy_bch + 0.373736339504 lime_bch + 0.494680435755 sulfuric_acid_bch --> 0.90867089595 3hp_bch + 0.0644008372188 biomass_bch + 0.0269282668315 waste_organic_bch + 0.686682596069 gypsum_bch
# BPR_glyc_3hp_scere_pt150_mu_0.053_aeroFB_ctrf_evapM: glyc_bch + 35.4239706468 energy_bch + 0.344272637191 lime_bch + 0.455682041543 sulfuric_acid_bch --> 0.837035344495 3hp_bch + 0.128801674438 biomass_bch + 0.0341629810672 waste_organic_bch + 0.632547609835 gypsum_bch
# BPR_glyc_3hp_scere_pt150_mu_0.08_aeroFB_ctrf_evapM: glyc_bch + 15.0051032626 energy_bch + 0.29701299979 lime_bch + 0.393128804002 sulfuric_acid_bch --> 0.722132263045 3hp_bch + 0.193202511656 biomass_bch + 0.0846652252987 waste_organic_bch + 0.545715351183 gypsum_bch
# BPR_glyc_3hp_scere_pt150_mu_0.107_aeroFB_ctrf_evapM: glyc_bch + 11.0386184945 energy_bch + 0.248073245231 lime_bch + 0.328351749827 sulfuric_acid_bch --> 0.60314428697 3hp_bch + 0.257603348875 biomass_bch + 0.139252364155 waste_organic_bch + 0.455796137663 gypsum_bch
# BPR_glyc_3hp_scere_pt150_mu_0.133_aeroFB_ctrf_evapM: glyc_bch + 8.17910512824 energy_bch + 0.199133490671 lime_bch + 0.263574695651 sulfuric_acid_bch --> 0.484156310895 3hp_bch + 0.322004186094 biomass_bch + 0.193839503011 waste_organic_bch + 0.365876924144 gypsum_bch
# BPR_glyc_3hp_scere_pt150_mu_0.16_aeroFB_ctrf_evapM: glyc_bch + 7.37475848548 energy_bch + 0.150193736112 lime_bch + 0.198797641476 sulfuric_acid_bch --> 0.365168334821 3hp_bch + 0.386405023313 biomass_bch + 0.248426641866 waste_organic_bch + 0.275957710624 gypsum_bch
# BPR_glyc_3hp_scere_pt150_mu_0.187_aeroFB_ctrf_evapM: glyc_bch + 6.78328864147 energy_bch + 0.100398837694 lime_bch + 0.132888711988 sulfuric_acid_bch --> 0.244101234365 3hp_bch + 0.450805860532 biomass_bch + 0.305092905103 waste_organic_bch + 0.18446730281 gypsum_bch
# BPR_glyc_3hp_scere_pt150_mu_0.214_aeroFB_ctrf_evapM: glyc_bch + 6.33378822217 energy_bch + 0.0502135695175 lime_bch + 0.0664630859357 sulfuric_acid_bch --> 0.122085021924 3hp_bch + 0.515206697751 biomass_bch + 0.362708280325 waste_organic_bch + 0.0922596510683 gypsum_bch
# BPR_glc_1,3pdo_scere_pt150_mu_0.048_anaeFB_ctrf_evapM: glc_bch + 8.6709533443 energy_bch --> 0.581902556632 1,3pdo_bch + 0.0132142046136 biomass_bch + 0.404883238755 waste_organic_bch
# BPR_glc_1,3pdo_scere_pt150_mu_0.095_anaeFB_ctrf_evapM: glc_bch + 4.216434159 energy_bch --> 0.538071928178 1,3pdo_bch + 0.0264284092271 biomass_bch + 0.435499662595 waste_organic_bch
# BPR_glc_1,3pdo_scere_pt150_mu_0.143_anaeFB_ctrf_evapM: glc_bch + 3.58664911099 energy_bch --> 0.494241299725 1,3pdo_bch + 0.0396426138407 biomass_bch + 0.466116086435 waste_organic_bch
# BPR_glc_1,3pdo_scere_pt150_mu_0.19_anaeFB_ctrf_evapM: glc_bch + 3.3347322763 energy_bch --> 0.450290104848 1,3pdo_bch + 0.0528568184542 biomass_bch + 0.496853076697 waste_organic_bch
# BPR_glc_1,3pdo_scere_pt150_mu_0.238_anaeFB_ctrf_evapM: glc_bch + 3.24271806844 energy_bch --> 0.402866173872 1,3pdo_bch + 0.0660710230678 biomass_bch + 0.53106280306 waste_organic_bch
# BPR_glc_1,3pdo_scere_pt150_mu_0.286_anaeFB_ctrf_evapM: glc_bch + 3.17944689959 energy_bch --> 0.317222135549 1,3pdo_bch + 0.0792852276813 biomass_bch + 0.60349263677 waste_organic_bch
# BPR_glc_1,3pdo_scere_pt150_mu_0.333_anaeFB_ctrf_evapM: glc_bch + 3.13343237204 energy_bch --> 0.231149809813 1,3pdo_bch + 0.0924994322949 biomass_bch + 0.676350757893 waste_organic_bch
# BPR_glc_1,3pdo_scere_pt150_mu_0.381_anaeFB_ctrf_evapM: glc_bch + 3.0969667943 energy_bch --> 0.144858239412 1,3pdo_bch + 0.105713636908 biomass_bch + 0.74942812368 waste_organic_bch
# BPR_glc_1,3pdo_scere_pt150_mu_0.429_anaeFB_ctrf_evapM: glc_bch + 3.07015884364 energy_bch --> 0.0143822823784 1,3pdo_bch + 0.118927841522 biomass_bch + 0.8666898761 waste_organic_bch
# BPR_glc_3hp_scere_pt150_mu_0.048_anaeFB_ctrf_evapM: glc_bch + 8.70308322584 energy_bch + 0.358655890265 lime_bch + 0.474719831413 sulfuric_acid_bch --> 0.872005568357 3hp_bch + 0.0132142046136 biomass_bch + 0.11478022703 waste_organic_bch + 0.658974608007 gypsum_bch
# BPR_glc_3hp_scere_pt150_mu_0.095_anaeFB_ctrf_evapM: glc_bch + 5.93131147677 energy_bch + 0.31410924928 lime_bch + 0.415757537827 sulfuric_acid_bch --> 0.763698636714 3hp_bch + 0.0264284092271 biomass_bch + 0.209872954059 waste_organic_bch + 0.577127059765 gypsum_bch
# BPR_glc_3hp_scere_pt150_mu_0.143_anaeFB_ctrf_evapM: glc_bch + 4.73128795093 energy_bch + 0.269562608296 lime_bch + 0.35679524424 sulfuric_acid_bch --> 0.655391705071 3hp_bch + 0.0396426138407 biomass_bch + 0.304965681089 waste_organic_bch + 0.495279511522 gypsum_bch
# BPR_glc_3hp_scere_pt150_mu_0.19_anaeFB_ctrf_evapM: glc_bch + 3.79420043038 energy_bch + 0.225015967311 lime_bch + 0.297832950654 sulfuric_acid_bch --> 0.547084773427 3hp_bch + 0.0528568184542 biomass_bch + 0.400058408118 waste_organic_bch + 0.413431963279 gypsum_bch
# BPR_glc_3hp_scere_pt150_mu_0.238_anaeFB_ctrf_evapM: glc_bch + 3.24270361603 energy_bch + 0.180433808956 lime_bch + 0.238823645989 sulfuric_acid_bch --> 0.438691487857 3hp_bch + 0.0660710230678 biomass_bch + 0.495237489075 waste_organic_bch + 0.331519157374 gypsum_bch
# BPR_glc_3hp_scere_pt150_mu_0.286_anaeFB_ctrf_evapM: glc_bch + 3.17930553603 energy_bch + 0.135572811927 lime_bch + 0.179445268206 sulfuric_acid_bch --> 0.329620257542 3hp_bch + 0.0792852276813 biomass_bch + 0.591094514777 waste_organic_bch + 0.249094028625 gypsum_bch
# BPR_glc_3hp_scere_pt150_mu_0.333_anaeFB_ctrf_evapM: glc_bch + 3.13344137505 energy_bch + 0.0903894680816 lime_bch + 0.119640229574 sulfuric_acid_bch --> 0.219765300466 3hp_bch + 0.0924994322949 biomass_bch + 0.687735267239 waste_organic_bch + 0.166076637562 gypsum_bch
# BPR_glc_3hp_scere_pt150_mu_0.381_anaeFB_ctrf_evapM: glc_bch + 3.09700330653 energy_bch + 0.0452061242361 lime_bch + 0.0598351909413 sulfuric_acid_bch --> 0.10991034339 3hp_bch + 0.105713636908 biomass_bch + 0.784376019702 waste_organic_bch + 0.0830592464995 gypsum_bch
# BPR_glc_3hp_scere_pt150_mu_0.429_anaeFB_ctrf_evapM: glc_bch + 2.82476856892 energy_bch + 2.27803906333e-05 lime_bch + 3.01523089248e-05 sulfuric_acid_bch --> 5.53863132344e-05 3hp_bch + 0.118927841522 biomass_bch + 0.881016772165 waste_organic_bch + 4.18554369113e-05 gypsum_bch
